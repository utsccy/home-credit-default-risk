# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
import numpy as np

# %%
#define utilities functions
def remove_num_outlier(df):
    """
    Replace 365243 with np.nan in date columns of df
    
    """
    for col in df.columns:
        if "DAYS" in col:
            df[col] = df[col].replace({365243: np.nan})

    return df

def remove_cat_outlier(df):
    """
    Replace XNA values in df which represents na in the categorical columns with n/a
    
    """
    categorical_col = [f for f in df.columns if df[f].dtype=="object"]
    for col in categorical_col:
        if df[col][df[col]=='XNA'].shape[0] > 0:
            df[col].replace('XNA', np.nan)
    return df

def downcast_dtypes(df):
    """
    Downsize float64/int64 with float32/int32 to save memory space
    """
    float_cols = [c for c in df if df[c].dtype == "float64"]
    int_cols =   [c for c in df if df[c].dtype in ["int64"]]

    df[float_cols] = df[float_cols].astype(np.float32)
    df[int_cols]   = df[int_cols].astype(np.int32)

    return df

def one_hot_encoder(df, nan_as_category = True):
    """
    One-hot encoding for categorical columns with get_dummies
    """
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

def remove_missing_col_with_threshold(df,threshold=0.6):
    """
    remove columns that has missing values more than threshold%
    """
    miss_data = pd.DataFrame((df.isnull().sum())*100/df.shape[0])
    miss_data_col=miss_data[miss_data[0]>threshold].index
    df_new  = df[[i for i in df.columns if i not in miss_data_col]]
    return df_new

# %%
prev_app = pd.read_csv('../input/previous_application.zip')

# %%
prev_app, categorical_cols = one_hot_encoder(prev_app, nan_as_category= True)

# %% [markdown]
# ### Missing data and outier Treatment

# %%
#replace 365243 with na in numerical columns
remove_num_outlier(prev_app)
#replace XNA with na in the categorical columns
remove_cat_outlier(prev_app)
# Out:
#          prev_app_id  curr_app_id  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 0            5319600       657807     6404.310        58905.000    65124.00
# 1            5697773       555192     6264.000        39145.500    35230.50
# 2            4742836       578775     4951.350        47056.275    52641.00
# 3            4114563       740578     3391.110        35144.370    30586.50
# 4            4236686       852791    14713.605       123486.075   120307.50
# ...              ...          ...          ...              ...         ...
# 1670209      4094373       710347     5009.400       108180.000   108180.00
# 1670210      5345589       563998    11269.575        80995.185    59503.50
# 1670211      5963924       654249     8797.680        79416.900    60673.50
# 1670212      4832310       887003          NaN        41499.000    41499.00
# 1670213      5092525       963026          NaN        30912.750    30912.75
#
#          AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  HOUR_APPR_PROCESS_START  \
# 0                   0.000        58905.000                        8
# 1                3915.000        39145.500                        8
# 2                   4.275        47056.275                       13
# 3                7032.870        35144.370                        9
# 4               12349.575       123486.075                       13
# ...                   ...              ...                      ...
# 1670209             0.000       108180.000                       17
# 1670210         24299.685        80995.185                       18
# 1670211         22500.900        79416.900                       19
# 1670212             0.000        41499.000                       10
# 1670213             0.000        30912.750                       19
#
#          NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  ...  \
# 0                             1           0.000000  ...
# 1                             1           0.108922  ...
# 2                             1           0.000088  ...
# 3                             1           0.203603  ...
# 4                             1           0.101388  ...
# ...                         ...                ...  ...
# 1670209                       1           0.000000  ...
# 1670210                       1           0.315794  ...
# 1670211                       1           0.294628  ...
# 1670212                       1           0.000000  ...
# 1670213                       1           0.000000  ...
#
#          PRODUCT_COMBINATION_Cash X-Sell: middle  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 1670209                                        0
# 1670210                                        0
# 1670211                                        0
# 1670212                                        0
# 1670213                                        0
#
#          PRODUCT_COMBINATION_POS household with interest  \
# 0                                                      0
# 1                                                      1
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 1670209                                                0
# 1670210                                                1
# 1670211                                                1
# 1670212                                                0
# 1670213                                                0
#
#          PRODUCT_COMBINATION_POS household without interest  \
# 0                                                        0
# 1                                                        0
# 2                                                        1
# 3                                                        1
# 4                                                        0
# ...                                                    ...
# 1670209                                                  1
# 1670210                                                  0
# 1670211                                                  0
# 1670212                                                  0
# 1670213                                                  0
#
#          PRODUCT_COMBINATION_POS industry with interest  \
# 0                                                     1
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     1
# ...                                                 ...
# 1670209                                               0
# 1670210                                               0
# 1670211                                               0
# 1670212                                               0
# 1670213                                               0
#
#          PRODUCT_COMBINATION_POS industry without interest  \
# 0                                                        0
# 1                                                        0
# 2                                                        0
# 3                                                        0
# 4                                                        0
# ...                                                    ...
# 1670209                                                  0
# 1670210                                                  0
# 1670211                                                  0
# 1670212                                                  0
# 1670213                                                  0
#
#          PRODUCT_COMBINATION_POS mobile with interest  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 1670209                                             0
# 1670210                                             0
# 1670211                                             0
# 1670212                                             1
# 1670213                                             1
#
#          PRODUCT_COMBINATION_POS mobile without interest  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 1670209                                                0
# 1670210                                                0
# 1670211                                                0
# 1670212                                                0
# 1670213                                                0
#
#          PRODUCT_COMBINATION_POS other with interest  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 1670209                                            0
# 1670210                                            0
# 1670211                                            0
# 1670212                                            0
# 1670213                                            0
#
#          PRODUCT_COMBINATION_POS others without interest  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 1670209                                                0
# 1670210                                                0
# 1670211                                                0
# 1670212                                                0
# 1670213                                                0
#
#          PRODUCT_COMBINATION_nan
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 1670209                        0
# 1670210                        0
# 1670211                        0
# 1670212                        0
# 1670213                        0
#
# [1670214 rows x 180 columns]

# %% [markdown]
# ## Feature engineering
# ### Add new features

# %%
prev_app['APP_CREDIT_PERC'] = prev_app['AMT_APPLICATION'] / prev_app['AMT_CREDIT']
prev_app['AMT_CREDIT_GOODS_PERC'] = prev_app['AMT_CREDIT'] / prev_app['AMT_GOODS_PRICE']
prev_app['AMT_PAY_YEAR'] = prev_app['AMT_CREDIT'] / prev_app['AMT_ANNUITY']

# %% [markdown]
# ### Data Aggregation

# %%
num_features = [f_ for f_ in prev_app.columns.values if (f_.find('DAYS')>=0) | (f_.find('RATE')>=0) | (f_.find('AMT')>=0)]
num_features
# Out:
# ['AMT_ANNUITY',
#  'AMT_APPLICATION',
#  'AMT_CREDIT',
#  'AMT_DOWN_PAYMENT',
#  'AMT_GOODS_PRICE',
#  'RATE_DOWN_PAYMENT',
#  'RATE_INTEREST_PRIMARY',
#  'RATE_INTEREST_PRIVILEGED',
#  'DAYS_DECISION',
#  'DAYS_FIRST_DRAWING',
#  'DAYS_FIRST_DUE',
#  'DAYS_LAST_DUE_1ST_VERSION',
#  'DAYS_LAST_DUE',
#  'DAYS_TERMINATION',
#  'AMT_CREDIT_GOODS_PERC',
#  'AMT_PAY_YEAR']

# %%
num_aggregations = {
'AMT_ANNUITY':['mean','max'],
 'AMT_APPLICATION':['mean','max'],
 'AMT_CREDIT':['mean','max'],
 'AMT_DOWN_PAYMENT':['mean','max'],
 'AMT_GOODS_PRICE':['mean','max'],
 'RATE_DOWN_PAYMENT':['mean'],
 'RATE_INTEREST_PRIMARY':['mean'],
 'RATE_INTEREST_PRIVILEGED':['mean'],
 'DAYS_DECISION':['mean','max','min'],
 'DAYS_FIRST_DRAWING':['mean','max'],
 'DAYS_FIRST_DUE':['mean','max'],
 'DAYS_LAST_DUE_1ST_VERSION':['mean','max'],
 'DAYS_LAST_DUE':['mean','max'],
 'DAYS_TERMINATION':['mean','max'],
 'AMT_CREDIT_GOODS_PERC':['mean','max'],
 'AMT_PAY_YEAR':['mean','max']
}

# %%
cat_aggregations = dict(zip(categorical_cols,['mean']*len(categorical_cols)))

# %%
aggregations = {**num_aggregations, **cat_aggregations}
prev_app_agg = prev_app.groupby('curr_app_id').agg(aggregations)
prev_app_agg.columns = pd.Index(['PREV_APP_' + col[0] + "_" + col[1].upper() for col in prev_app_agg.columns.tolist()])

# %% [markdown]
# #### Previous loans with status: Approved

# %%
prev_app_approved = prev_app[prev_app['NAME_CONTRACT_STATUS_Approved'] == 1]
prev_app_approved_agg = prev_app_approved.groupby('curr_app_id').agg(num_aggregations)
prev_app_approved_agg.columns = pd.Index(['PREV_APP_APPROVED_' + col[0] + "_" + col[1].upper() for col in prev_app_approved_agg.columns.tolist()])
prev_app_approved_agg.columns
prev_app_agg = prev_app_agg.join(prev_app_approved_agg, how='left', on='curr_app_id')

# %% [markdown]
# #### Previous loans with status: Refused

# %%
prev_app_refused = prev_app[prev_app['NAME_CONTRACT_STATUS_Refused'] == 1]
prev_app_refused_agg = prev_app_refused.groupby('curr_app_id').agg(num_aggregations)
prev_app_refused_agg.columns = pd.Index(['PREV_APP_REFUSED_' + col[0] + "_" + col[1].upper() for col in prev_app_refused_agg.columns.tolist()])
prev_app_refused_agg.columns
prev_app_agg = prev_app_agg.join(prev_app_refused_agg, how='left', on='curr_app_id')

# %%
prev_app_agg=prev_app_agg.reset_index()
downcast_dtypes(prev_app_agg)
prev_app_agg.info(verbose=True,memory_usage=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338857 entries, 0 to 338856
# Data columns (total 250 columns):
#  #    Column                                                                     Non-Null Count   Dtype
# ---   ------                                                                     --------------   -----
#  0    curr_app_id                                                                338857 non-null  int32
#  1    PREV_APP_AMT_ANNUITY_MEAN                                                  338377 non-null  float32
#  2    PREV_APP_AMT_ANNUITY_MAX                                                   338377 non-null  float32
#  3    PREV_APP_AMT_APPLICATION_MEAN                                              338857 non-null  float32
#  4    PREV_APP_AMT_APPLICATION_MAX                                               338857 non-null  float32
#  5    PREV_APP_AMT_CREDIT_MEAN                                                   338857 non-null  float32
#  6    PREV_APP_AMT_CREDIT_MAX                                                    338857 non-null  float32
#  7    PREV_APP_AMT_DOWN_PAYMENT_MEAN                                             318753 non-null  float32
#  8    PREV_APP_AMT_DOWN_PAYMENT_MAX                                              318753 non-null  float32
#  9    PREV_APP_AMT_GOODS_PRICE_MEAN                                              337793 non-null  float32
#  10   PREV_APP_AMT_GOODS_PRICE_MAX                                               337793 non-null  float32
#  11   PREV_APP_RATE_DOWN_PAYMENT_MEAN                                            318753 non-null  float32
#  12   PREV_APP_RATE_INTEREST_PRIMARY_MEAN                                        5721 non-null    float32
#  13   PREV_APP_RATE_INTEREST_PRIVILEGED_MEAN                                     5721 non-null    float32
#  14   PREV_APP_DAYS_DECISION_MEAN                                                338857 non-null  float32
#  15   PREV_APP_DAYS_DECISION_MAX                                                 338857 non-null  int32
#  16   PREV_APP_DAYS_DECISION_MIN                                                 338857 non-null  int32
#  17   PREV_APP_DAYS_FIRST_DRAWING_MEAN                                           62503 non-null   float32
#  18   PREV_APP_DAYS_FIRST_DRAWING_MAX                                            62503 non-null   float32
#  19   PREV_APP_DAYS_FIRST_DUE_MEAN                                               336738 non-null  float32
#  20   PREV_APP_DAYS_FIRST_DUE_MAX                                                336738 non-null  float32
#  21   PREV_APP_DAYS_LAST_DUE_1ST_VERSION_MEAN                                    334420 non-null  float32
#  22   PREV_APP_DAYS_LAST_DUE_1ST_VERSION_MAX                                     334420 non-null  float32
#  23   PREV_APP_DAYS_LAST_DUE_MEAN                                                313922 non-null  float32
#  24   PREV_APP_DAYS_LAST_DUE_MAX                                                 313922 non-null  float32
#  25   PREV_APP_DAYS_TERMINATION_MEAN                                             311580 non-null  float32
#  26   PREV_APP_DAYS_TERMINATION_MAX                                              311580 non-null  float32
#  27   PREV_APP_AMT_CREDIT_GOODS_PERC_MEAN                                        337784 non-null  float32
#  28   PREV_APP_AMT_CREDIT_GOODS_PERC_MAX                                         337784 non-null  float32
#  29   PREV_APP_AMT_PAY_YEAR_MEAN                                                 338376 non-null  float32
#  30   PREV_APP_AMT_PAY_YEAR_MAX                                                  338376 non-null  float32
#  31   PREV_APP_NAME_CONTRACT_TYPE_Cash loans_MEAN                                338857 non-null  float32
#  32   PREV_APP_NAME_CONTRACT_TYPE_Consumer loans_MEAN                            338857 non-null  float32
#  33   PREV_APP_NAME_CONTRACT_TYPE_Revolving loans_MEAN                           338857 non-null  float32
#  34   PREV_APP_NAME_CONTRACT_TYPE_XNA_MEAN                                       338857 non-null  float32
#  35   PREV_APP_NAME_CONTRACT_TYPE_nan_MEAN                                       338857 non-null  uint8
#  36   PREV_APP_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN                            338857 non-null  float32
#  37   PREV_APP_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN                            338857 non-null  float32
#  38   PREV_APP_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN                          338857 non-null  float32
#  39   PREV_APP_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                            338857 non-null  float32
#  40   PREV_APP_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                          338857 non-null  float32
#  41   PREV_APP_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                           338857 non-null  float32
#  42   PREV_APP_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN                         338857 non-null  float32
#  43   PREV_APP_WEEKDAY_APPR_PROCESS_START_nan_MEAN                               338857 non-null  uint8
#  44   PREV_APP_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN                                338857 non-null  float32
#  45   PREV_APP_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN                                338857 non-null  float32
#  46   PREV_APP_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN                              338857 non-null  uint8
#  47   PREV_APP_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN          338857 non-null  float32
#  48   PREV_APP_NAME_CASH_LOAN_PURPOSE_Business development_MEAN                  338857 non-null  float32
#  49   PREV_APP_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN                       338857 non-null  float32
#  50   PREV_APP_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN          338857 non-null  float32
#  51   PREV_APP_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN                         338857 non-null  float32
#  52   PREV_APP_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN                      338857 non-null  float32
#  53   PREV_APP_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN                     338857 non-null  float32
#  54   PREV_APP_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN                           338857 non-null  float32
#  55   PREV_APP_NAME_CASH_LOAN_PURPOSE_Education_MEAN                             338857 non-null  float32
#  56   PREV_APP_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN                     338857 non-null  float32
#  57   PREV_APP_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN                             338857 non-null  float32
#  58   PREV_APP_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN           338857 non-null  float32
#  59   PREV_APP_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                                 338857 non-null  float32
#  60   PREV_APP_NAME_CASH_LOAN_PURPOSE_Journey_MEAN                               338857 non-null  float32
#  61   PREV_APP_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN                              338857 non-null  float32
#  62   PREV_APP_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN              338857 non-null  float32
#  63   PREV_APP_NAME_CASH_LOAN_PURPOSE_Other_MEAN                                 338857 non-null  float32
#  64   PREV_APP_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN               338857 non-null  float32
#  65   PREV_APP_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN      338857 non-null  float32
#  66   PREV_APP_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN              338857 non-null  float32
#  67   PREV_APP_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN                               338857 non-null  float32
#  68   PREV_APP_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN                          338857 non-null  float32
#  69   PREV_APP_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN              338857 non-null  float32
#  70   PREV_APP_NAME_CASH_LOAN_PURPOSE_XAP_MEAN                                   338857 non-null  float32
#  71   PREV_APP_NAME_CASH_LOAN_PURPOSE_XNA_MEAN                                   338857 non-null  float32
#  72   PREV_APP_NAME_CASH_LOAN_PURPOSE_nan_MEAN                                   338857 non-null  uint8
#  73   PREV_APP_NAME_CONTRACT_STATUS_Approved_MEAN                                338857 non-null  float32
#  74   PREV_APP_NAME_CONTRACT_STATUS_Canceled_MEAN                                338857 non-null  float32
#  75   PREV_APP_NAME_CONTRACT_STATUS_Refused_MEAN                                 338857 non-null  float32
#  76   PREV_APP_NAME_CONTRACT_STATUS_Unused offer_MEAN                            338857 non-null  float32
#  77   PREV_APP_NAME_CONTRACT_STATUS_nan_MEAN                                     338857 non-null  uint8
#  78   PREV_APP_NAME_PAYMENT_TYPE_Cash through the bank_MEAN                      338857 non-null  float32
#  79   PREV_APP_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN  338857 non-null  float32
#  80   PREV_APP_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN                 338857 non-null  float32
#  81   PREV_APP_NAME_PAYMENT_TYPE_XNA_MEAN                                        338857 non-null  float32
#  82   PREV_APP_NAME_PAYMENT_TYPE_nan_MEAN                                        338857 non-null  uint8
#  83   PREV_APP_CODE_REJECT_REASON_CLIENT_MEAN                                    338857 non-null  float32
#  84   PREV_APP_CODE_REJECT_REASON_HC_MEAN                                        338857 non-null  float32
#  85   PREV_APP_CODE_REJECT_REASON_LIMIT_MEAN                                     338857 non-null  float32
#  86   PREV_APP_CODE_REJECT_REASON_SCO_MEAN                                       338857 non-null  float32
#  87   PREV_APP_CODE_REJECT_REASON_SCOFR_MEAN                                     338857 non-null  float32
#  88   PREV_APP_CODE_REJECT_REASON_SYSTEM_MEAN                                    338857 non-null  float32
#  89   PREV_APP_CODE_REJECT_REASON_VERIF_MEAN                                     338857 non-null  float32
#  90   PREV_APP_CODE_REJECT_REASON_XAP_MEAN                                       338857 non-null  float32
#  91   PREV_APP_CODE_REJECT_REASON_XNA_MEAN                                       338857 non-null  float32
#  92   PREV_APP_CODE_REJECT_REASON_nan_MEAN                                       338857 non-null  uint8
#  93   PREV_APP_NAME_TYPE_SUITE_Children_MEAN                                     338857 non-null  float32
#  94   PREV_APP_NAME_TYPE_SUITE_Family_MEAN                                       338857 non-null  float32
#  95   PREV_APP_NAME_TYPE_SUITE_Group of people_MEAN                              338857 non-null  float32
#  96   PREV_APP_NAME_TYPE_SUITE_Other_A_MEAN                                      338857 non-null  float32
#  97   PREV_APP_NAME_TYPE_SUITE_Other_B_MEAN                                      338857 non-null  float32
#  98   PREV_APP_NAME_TYPE_SUITE_Spouse, partner_MEAN                              338857 non-null  float32
#  99   PREV_APP_NAME_TYPE_SUITE_Unaccompanied_MEAN                                338857 non-null  float32
#  100  PREV_APP_NAME_TYPE_SUITE_nan_MEAN                                          338857 non-null  float32
#  101  PREV_APP_NAME_CLIENT_TYPE_New_MEAN                                         338857 non-null  float32
#  102  PREV_APP_NAME_CLIENT_TYPE_Refreshed_MEAN                                   338857 non-null  float32
#  103  PREV_APP_NAME_CLIENT_TYPE_Repeater_MEAN                                    338857 non-null  float32
#  104  PREV_APP_NAME_CLIENT_TYPE_XNA_MEAN                                         338857 non-null  float32
#  105  PREV_APP_NAME_CLIENT_TYPE_nan_MEAN                                         338857 non-null  uint8
#  106  PREV_APP_NAME_GOODS_CATEGORY_Additional Service_MEAN                       338857 non-null  float32
#  107  PREV_APP_NAME_GOODS_CATEGORY_Animals_MEAN                                  338857 non-null  float32
#  108  PREV_APP_NAME_GOODS_CATEGORY_Audio/Video_MEAN                              338857 non-null  float32
#  109  PREV_APP_NAME_GOODS_CATEGORY_Auto Accessories_MEAN                         338857 non-null  float32
#  110  PREV_APP_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN                 338857 non-null  float32
#  111  PREV_APP_NAME_GOODS_CATEGORY_Computers_MEAN                                338857 non-null  float32
#  112  PREV_APP_NAME_GOODS_CATEGORY_Construction Materials_MEAN                   338857 non-null  float32
#  113  PREV_APP_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN                     338857 non-null  float32
#  114  PREV_APP_NAME_GOODS_CATEGORY_Direct Sales_MEAN                             338857 non-null  float32
#  115  PREV_APP_NAME_GOODS_CATEGORY_Education_MEAN                                338857 non-null  float32
#  116  PREV_APP_NAME_GOODS_CATEGORY_Fitness_MEAN                                  338857 non-null  float32
#  117  PREV_APP_NAME_GOODS_CATEGORY_Furniture_MEAN                                338857 non-null  float32
#  118  PREV_APP_NAME_GOODS_CATEGORY_Gardening_MEAN                                338857 non-null  float32
#  119  PREV_APP_NAME_GOODS_CATEGORY_Homewares_MEAN                                338857 non-null  float32
#  120  PREV_APP_NAME_GOODS_CATEGORY_House Construction_MEAN                       338857 non-null  float32
#  121  PREV_APP_NAME_GOODS_CATEGORY_Insurance_MEAN                                338857 non-null  float32
#  122  PREV_APP_NAME_GOODS_CATEGORY_Jewelry_MEAN                                  338857 non-null  float32
#  123  PREV_APP_NAME_GOODS_CATEGORY_Medical Supplies_MEAN                         338857 non-null  float32
#  124  PREV_APP_NAME_GOODS_CATEGORY_Medicine_MEAN                                 338857 non-null  float32
#  125  PREV_APP_NAME_GOODS_CATEGORY_Mobile_MEAN                                   338857 non-null  float32
#  126  PREV_APP_NAME_GOODS_CATEGORY_Office Appliances_MEAN                        338857 non-null  float32
#  127  PREV_APP_NAME_GOODS_CATEGORY_Other_MEAN                                    338857 non-null  float32
#  128  PREV_APP_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN                 338857 non-null  float32
#  129  PREV_APP_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN                        338857 non-null  float32
#  130  PREV_APP_NAME_GOODS_CATEGORY_Tourism_MEAN                                  338857 non-null  float32
#  131  PREV_APP_NAME_GOODS_CATEGORY_Vehicles_MEAN                                 338857 non-null  float32
#  132  PREV_APP_NAME_GOODS_CATEGORY_Weapon_MEAN                                   338857 non-null  float32
#  133  PREV_APP_NAME_GOODS_CATEGORY_XNA_MEAN                                      338857 non-null  float32
#  134  PREV_APP_NAME_GOODS_CATEGORY_nan_MEAN                                      338857 non-null  uint8
#  135  PREV_APP_NAME_PORTFOLIO_Cards_MEAN                                         338857 non-null  float32
#  136  PREV_APP_NAME_PORTFOLIO_Cars_MEAN                                          338857 non-null  float32
#  137  PREV_APP_NAME_PORTFOLIO_Cash_MEAN                                          338857 non-null  float32
#  138  PREV_APP_NAME_PORTFOLIO_POS_MEAN                                           338857 non-null  float32
#  139  PREV_APP_NAME_PORTFOLIO_XNA_MEAN                                           338857 non-null  float32
#  140  PREV_APP_NAME_PORTFOLIO_nan_MEAN                                           338857 non-null  uint8
#  141  PREV_APP_NAME_PRODUCT_TYPE_XNA_MEAN                                        338857 non-null  float32
#  142  PREV_APP_NAME_PRODUCT_TYPE_walk-in_MEAN                                    338857 non-null  float32
#  143  PREV_APP_NAME_PRODUCT_TYPE_x-sell_MEAN                                     338857 non-null  float32
#  144  PREV_APP_NAME_PRODUCT_TYPE_nan_MEAN                                        338857 non-null  uint8
#  145  PREV_APP_CHANNEL_TYPE_AP+ (Cash loan)_MEAN                                 338857 non-null  float32
#  146  PREV_APP_CHANNEL_TYPE_Car dealer_MEAN                                      338857 non-null  float32
#  147  PREV_APP_CHANNEL_TYPE_Channel of corporate sales_MEAN                      338857 non-null  float32
#  148  PREV_APP_CHANNEL_TYPE_Contact center_MEAN                                  338857 non-null  float32
#  149  PREV_APP_CHANNEL_TYPE_Country-wide_MEAN                                    338857 non-null  float32
#  150  PREV_APP_CHANNEL_TYPE_Credit and cash offices_MEAN                         338857 non-null  float32
#  151  PREV_APP_CHANNEL_TYPE_Regional / Local_MEAN                                338857 non-null  float32
#  152  PREV_APP_CHANNEL_TYPE_Stone_MEAN                                           338857 non-null  float32
#  153  PREV_APP_CHANNEL_TYPE_nan_MEAN                                             338857 non-null  uint8
#  154  PREV_APP_NAME_SELLER_INDUSTRY_Auto technology_MEAN                         338857 non-null  float32
#  155  PREV_APP_NAME_SELLER_INDUSTRY_Clothing_MEAN                                338857 non-null  float32
#  156  PREV_APP_NAME_SELLER_INDUSTRY_Connectivity_MEAN                            338857 non-null  float32
#  157  PREV_APP_NAME_SELLER_INDUSTRY_Construction_MEAN                            338857 non-null  float32
#  158  PREV_APP_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN                    338857 non-null  float32
#  159  PREV_APP_NAME_SELLER_INDUSTRY_Furniture_MEAN                               338857 non-null  float32
#  160  PREV_APP_NAME_SELLER_INDUSTRY_Industry_MEAN                                338857 non-null  float32
#  161  PREV_APP_NAME_SELLER_INDUSTRY_Jewelry_MEAN                                 338857 non-null  float32
#  162  PREV_APP_NAME_SELLER_INDUSTRY_MLM partners_MEAN                            338857 non-null  float32
#  163  PREV_APP_NAME_SELLER_INDUSTRY_Tourism_MEAN                                 338857 non-null  float32
#  164  PREV_APP_NAME_SELLER_INDUSTRY_XNA_MEAN                                     338857 non-null  float32
#  165  PREV_APP_NAME_SELLER_INDUSTRY_nan_MEAN                                     338857 non-null  uint8
#  166  PREV_APP_NAME_YIELD_GROUP_XNA_MEAN                                         338857 non-null  float32
#  167  PREV_APP_NAME_YIELD_GROUP_high_MEAN                                        338857 non-null  float32
#  168  PREV_APP_NAME_YIELD_GROUP_low_action_MEAN                                  338857 non-null  float32
#  169  PREV_APP_NAME_YIELD_GROUP_low_normal_MEAN                                  338857 non-null  float32
#  170  PREV_APP_NAME_YIELD_GROUP_middle_MEAN                                      338857 non-null  float32
#  171  PREV_APP_NAME_YIELD_GROUP_nan_MEAN                                         338857 non-null  uint8
#  172  PREV_APP_PRODUCT_COMBINATION_Card Street_MEAN                              338857 non-null  float32
#  173  PREV_APP_PRODUCT_COMBINATION_Card X-Sell_MEAN                              338857 non-null  float32
#  174  PREV_APP_PRODUCT_COMBINATION_Cash_MEAN                                     338857 non-null  float32
#  175  PREV_APP_PRODUCT_COMBINATION_Cash Street: high_MEAN                        338857 non-null  float32
#  176  PREV_APP_PRODUCT_COMBINATION_Cash Street: low_MEAN                         338857 non-null  float32
#  177  PREV_APP_PRODUCT_COMBINATION_Cash Street: middle_MEAN                      338857 non-null  float32
#  178  PREV_APP_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN                        338857 non-null  float32
#  179  PREV_APP_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN                         338857 non-null  float32
#  180  PREV_APP_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN                      338857 non-null  float32
#  181  PREV_APP_PRODUCT_COMBINATION_POS household with interest_MEAN              338857 non-null  float32
#  182  PREV_APP_PRODUCT_COMBINATION_POS household without interest_MEAN           338857 non-null  float32
#  183  PREV_APP_PRODUCT_COMBINATION_POS industry with interest_MEAN               338857 non-null  float32
#  184  PREV_APP_PRODUCT_COMBINATION_POS industry without interest_MEAN            338857 non-null  float32
#  185  PREV_APP_PRODUCT_COMBINATION_POS mobile with interest_MEAN                 338857 non-null  float32
#  186  PREV_APP_PRODUCT_COMBINATION_POS mobile without interest_MEAN              338857 non-null  float32
#  187  PREV_APP_PRODUCT_COMBINATION_POS other with interest_MEAN                  338857 non-null  float32
#  188  PREV_APP_PRODUCT_COMBINATION_POS others without interest_MEAN              338857 non-null  float32
#  189  PREV_APP_PRODUCT_COMBINATION_nan_MEAN                                      338857 non-null  float32
#  190  PREV_APP_APPROVED_AMT_ANNUITY_MEAN                                         337696 non-null  float32
#  191  PREV_APP_APPROVED_AMT_ANNUITY_MAX                                          337696 non-null  float32
#  192  PREV_APP_APPROVED_AMT_APPLICATION_MEAN                                     337698 non-null  float32
#  193  PREV_APP_APPROVED_AMT_APPLICATION_MAX                                      337698 non-null  float32
#  194  PREV_APP_APPROVED_AMT_CREDIT_MEAN                                          337698 non-null  float32
#  195  PREV_APP_APPROVED_AMT_CREDIT_MAX                                           337698 non-null  float32
#  196  PREV_APP_APPROVED_AMT_DOWN_PAYMENT_MEAN                                    316052 non-null  float32
#  197  PREV_APP_APPROVED_AMT_DOWN_PAYMENT_MAX                                     316052 non-null  float32
#  198  PREV_APP_APPROVED_AMT_GOODS_PRICE_MEAN                                     336621 non-null  float32
#  199  PREV_APP_APPROVED_AMT_GOODS_PRICE_MAX                                      336621 non-null  float32
#  200  PREV_APP_APPROVED_RATE_DOWN_PAYMENT_MEAN                                   316052 non-null  float32
#  201  PREV_APP_APPROVED_RATE_INTEREST_PRIMARY_MEAN                               5721 non-null    float32
#  202  PREV_APP_APPROVED_RATE_INTEREST_PRIVILEGED_MEAN                            5721 non-null    float32
#  203  PREV_APP_APPROVED_DAYS_DECISION_MEAN                                       337698 non-null  float32
#  204  PREV_APP_APPROVED_DAYS_DECISION_MAX                                        337698 non-null  float32
#  205  PREV_APP_APPROVED_DAYS_DECISION_MIN                                        337698 non-null  float32
#  206  PREV_APP_APPROVED_DAYS_FIRST_DRAWING_MEAN                                  62503 non-null   float32
#  207  PREV_APP_APPROVED_DAYS_FIRST_DRAWING_MAX                                   62503 non-null   float32
#  208  PREV_APP_APPROVED_DAYS_FIRST_DUE_MEAN                                      336738 non-null  float32
#  209  PREV_APP_APPROVED_DAYS_FIRST_DUE_MAX                                       336738 non-null  float32
#  210  PREV_APP_APPROVED_DAYS_LAST_DUE_1ST_VERSION_MEAN                           334420 non-null  float32
#  211  PREV_APP_APPROVED_DAYS_LAST_DUE_1ST_VERSION_MAX                            334420 non-null  float32
#  212  PREV_APP_APPROVED_DAYS_LAST_DUE_MEAN                                       313922 non-null  float32
#  213  PREV_APP_APPROVED_DAYS_LAST_DUE_MAX                                        313922 non-null  float32
#  214  PREV_APP_APPROVED_DAYS_TERMINATION_MEAN                                    311580 non-null  float32
#  215  PREV_APP_APPROVED_DAYS_TERMINATION_MAX                                     311580 non-null  float32
#  216  PREV_APP_APPROVED_AMT_CREDIT_GOODS_PERC_MEAN                               336612 non-null  float32
#  217  PREV_APP_APPROVED_AMT_CREDIT_GOODS_PERC_MAX                                336612 non-null  float32
#  218  PREV_APP_APPROVED_AMT_PAY_YEAR_MEAN                                        337687 non-null  float32
#  219  PREV_APP_APPROVED_AMT_PAY_YEAR_MAX                                         337687 non-null  float32
#  220  PREV_APP_REFUSED_AMT_ANNUITY_MEAN                                          108096 non-null  float32
#  221  PREV_APP_REFUSED_AMT_ANNUITY_MAX                                           108096 non-null  float32
#  222  PREV_APP_REFUSED_AMT_APPLICATION_MEAN                                      118277 non-null  float32
#  223  PREV_APP_REFUSED_AMT_APPLICATION_MAX                                       118277 non-null  float32
#  224  PREV_APP_REFUSED_AMT_CREDIT_MEAN                                           118277 non-null  float32
#  225  PREV_APP_REFUSED_AMT_CREDIT_MAX                                            118277 non-null  float32
#  226  PREV_APP_REFUSED_AMT_DOWN_PAYMENT_MEAN                                     52605 non-null   float32
#  227  PREV_APP_REFUSED_AMT_DOWN_PAYMENT_MAX                                      52605 non-null   float32
#  228  PREV_APP_REFUSED_AMT_GOODS_PRICE_MEAN                                      110042 non-null  float32
#  229  PREV_APP_REFUSED_AMT_GOODS_PRICE_MAX                                       110042 non-null  float32
#  230  PREV_APP_REFUSED_RATE_DOWN_PAYMENT_MEAN                                    52605 non-null   float32
#  231  PREV_APP_REFUSED_RATE_INTEREST_PRIMARY_MEAN                                0 non-null       float32
#  232  PREV_APP_REFUSED_RATE_INTEREST_PRIVILEGED_MEAN                             0 non-null       float32
#  233  PREV_APP_REFUSED_DAYS_DECISION_MEAN                                        118277 non-null  float32
#  234  PREV_APP_REFUSED_DAYS_DECISION_MAX                                         118277 non-null  float32
#  235  PREV_APP_REFUSED_DAYS_DECISION_MIN                                         118277 non-null  float32
#  236  PREV_APP_REFUSED_DAYS_FIRST_DRAWING_MEAN                                   0 non-null       float32
#  237  PREV_APP_REFUSED_DAYS_FIRST_DRAWING_MAX                                    0 non-null       float32
#  238  PREV_APP_REFUSED_DAYS_FIRST_DUE_MEAN                                       0 non-null       float32
#  239  PREV_APP_REFUSED_DAYS_FIRST_DUE_MAX                                        0 non-null       float32
#  240  PREV_APP_REFUSED_DAYS_LAST_DUE_1ST_VERSION_MEAN                            0 non-null       float32
#  241  PREV_APP_REFUSED_DAYS_LAST_DUE_1ST_VERSION_MAX                             0 non-null       float32
#  242  PREV_APP_REFUSED_DAYS_LAST_DUE_MEAN                                        0 non-null       float32
#  243  PREV_APP_REFUSED_DAYS_LAST_DUE_MAX                                         0 non-null       float32
#  244  PREV_APP_REFUSED_DAYS_TERMINATION_MEAN                                     0 non-null       float32
#  245  PREV_APP_REFUSED_DAYS_TERMINATION_MAX                                      0 non-null       float32
#  246  PREV_APP_REFUSED_AMT_CREDIT_GOODS_PERC_MEAN                                109858 non-null  float32
#  247  PREV_APP_REFUSED_AMT_CREDIT_GOODS_PERC_MAX                                 109858 non-null  float32
#  248  PREV_APP_REFUSED_AMT_PAY_YEAR_MEAN                                         108090 non-null  float32
#  249  PREV_APP_REFUSED_AMT_PAY_YEAR_MAX                                          108090 non-null  float32
# dtypes: float32(233), int32(3), uint8(14)
# memory usage: 309.6 MB

# %%
prev_app_agg.to_csv('../staging/previous_application.csv', index=False, compression='zip')
